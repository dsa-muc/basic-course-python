# %% [markdown]
# <img src="https://static.wixstatic.com/media/64484b_829e39cd0bf4469aa86afb21b28c7e90~mv2.png" width="250" style="float: left;">

# %% [markdown]
# # Part 3: Basics in Data Visualisation
# ### Author: Niklas Walter

# %% [markdown]
# <hr style="border:1.5px solid gray"> </hr>

# %% [markdown]
# This notebook aims to provide an basic overview of important methods used for data visualisation in a data analytical context. The first two chapters present different methods within `matplotlib` and `seaborn`. In chapter three and four, we demonstrate two additional libraries, which extend the pool of basic modules. For example, we show how `bokeh` can be used to build interactive plots.
#
# The content of the notebook can be summarised as follows:

# %% [markdown]
# 1. [Matplotlib](#plt)<br/>
#     1.1 [A simple plot of a graph](#plt1)<br/>
#     1.2 [A simple empirical histogram](#plt2)<br/>
#     1.3 [Multiple plots](#plt3)<br/>
#     1.4 [Scatter plots](#plt4)<br/>
#     1.5 [3D plots](#plt5)<br/>
# 2. [Seaborn](#sns)<br/>
#     2.1 [Matplotlib vs. Seaborn](#sns1)<br/>
#     2.2 [Seaborn and dataframes](#sns2)<br/>
#     2.3 [Visualising time series](#sns3)<br/>
#     2.4 [Relation plots](#sns4)<br/>
#     2.5 [Empirical Histograms and Kernel Density Estimates (KDEs)](#sns5)<br/>
#     2.6 [Visualising correlations](#sns6)<br/>
#     2.7 [Visualising data in 2D](#sns7)<br/>
# 3. [Bokeh](#bokeh)
# 4. [WordCloud](#wc)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <hr style="border:1.5px solid gray"> </hr>

# %% [markdown]
# ## 5.1. Matplotlib
#
# <a id='plt'></a>

# %% [markdown]
# Matploblib can be seen as the cornerstone an most used environment for 2-dimensional plotting in Python and its numerical mathematics extension NumPy. In particular the procedural pyplot interface provides a MATLAB-like plotting framework. Therefore, the majority of plotting commands in pyplot have Matlab analogs with similar arguments.
#
#
# More information can be found under
#
# * https://matplotlib.org/index.html
# * https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# -----

# %% [markdown]
# ### A simple plot of a graph:
#
# <a id='plt1'></a>

# %% [markdown]
# For an exemplary function plot, we define the function $f: \mathbb{R}\rightarrow\mathbb{R}^+,\; f:x\mapsto e^{-x}$.

# %%
def f(x): 
    return np.exp(-x)

# %% [markdown]
# To illustrate the function, we generate a grid using the numpy method `np.linspace()`. To generate the plot the function `plt.plot()` takes the x-values and y-values as necessary arguments. Using the methods `plt.title()`, `plt.xlabel()` and `plt.ylabel()` we can add additional - but very important - information to the figure.

# %%
aa = np.linspace(0, 10, 100)
bb = f(aa)
plt.plot(aa, bb)
plt.title('Function $x \mapsto e^{-x}$')
plt.xlabel("$x$ values")
plt.ylabel('$e^{-x}$')
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# ### A simple empirical histogram:
#
# <a id='plt2'></a>

# %% [markdown]
# To analyze or model data it is often a good approach to try to understand the underlying distribution. A visualization of the (empirical) distribution can often provide early answers to many important questions. What range do the observations cover? What is their central tendency? Are they heavily skewed in one direction? Etc.

# %% [markdown]
# Perhaps the most common approach to visualizing a distribution is the histogram. A histogram is a bar plot where the axis representing the data variable is divided into a set of discrete bins and the count of observations falling within each bin is shown using the height of the corresponding bar.

# %% [markdown]
# Using the method `plt.hist()`, it is possible to plot an empirical histogram of a given random vector. In addition, it is possible to set the number of bins. By default the bins of the histogram show the absolute amount of observations. However, one can use the `density` argument to observe the relative occurrence of the observation.

# %%
xx = np.random.normal(size=20000)

plt.hist(xx, bins=50)
plt.title('Empirical histogram of a Gaussian sample (absolut)')
plt.show()

plt.hist(xx, bins=50, density = True)
plt.title('Empirical histogram of a Gaussian sample (density)')
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# ### Multiple plots (subplots):
#
# <a id='plt3'></a>

# %% [markdown]
# The avoid creating two plots seperately as above, one can use `plt.subplots()` to generate a blank canvas for several plots. In particular, the first argument `nrows` of the function defines the number of rows and the second `ncols`the number of columns. Moreover, it is possible to define the size of the graphic as shown in the next cell.

# %%
#This creates a blank canvas for 6 plots.
fig, ax = plt.subplots(nrows = 3, ncols = 2, figsize=(10, 6))
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# ### Scatter plots:
#
# <a id='plt4'></a>

# %% [markdown]
# Scatter plots are used to plot data points on the horizontal and vertical axis to visualise a possible dependence structure. To generate such a plot, one can use `plt.scatter()`. Using arguments like `color` or `marker` makes it possible to customize the plot.

# %%
n = 1000
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
#Accessing the first plot
plt.subplot(1, 2, 1)
aa = np.random.normal(0., 3., n)
bb = np.random.normal(0., 1., n)
plt.scatter(aa, bb, color='r')
plt.title('Scatter plot of a Gaussian sample')

#Accessing the second plot
plt.subplot(1, 2, 2)
aa = np.random.rand(n)
bb = np.random.rand(n)
plt.scatter(aa, bb, color='b', marker='+')
plt.title('Scatter plot of a Uniform sample')
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# ### 3D plots:
#
# <a id='plt5'></a>

# %% [markdown]
# An Axes3D object is created just like any other axes using the `projection=‘3d’` keyword. Using the `numpy` method `np.meshgrid`, we create a 2-dimensional grid on the X-Y plane. To plot the Z points, we use `plot_surface()`

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')
XX = np.arange(-5, 5, 0.5)
YY = np.arange(-5, 5, 0.5)
XX, YY = np.meshgrid(XX, YY)
ZZ = XX**2 - YY**2
surf = ax.plot_surface(XX, YY, ZZ)
ax.set_title('3D plot')
plt.show()

# %% [markdown]
# <hr style="border:1.5px solid gray"> </hr>

# %% [markdown]
# ## 5.2. Seaborn
#
# <a id='sns'></a>

# %% [markdown]
# Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures.
#
# Seaborn helps you explore and understand your data. Its plotting functions operate on dataframes and arrays containing whole datasets and internally perform the necessary semantic mapping and statistical aggregation to produce informative plots.
#
# More infos on https://seaborn.pydata.org/.

# %% [markdown]
# -----

# %% [markdown]
# ### Matplotlib vs. Seaborn:
# <a id='sns1'></a>

# %% [markdown]
# The following demonstrates the difference of the default `matplotlib` and `seaborn` design.

# %%
n, p = 100, 5
xx = np.linspace(0., 1., n)
yy = np.cumsum(np.random.randn(n, p), axis=0)

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline

# %%
plt.plot(xx, yy)
plt.legend('ABCDEF', ncol=2, loc='upper left')
plt.title("Matplotlib Plot")
plt.show()

# %%
import seaborn as sns
# Sets the visual framework of Seaborn
sns.set()
# Same plotting code as above!
plt.plot(xx, yy)
plt.legend('ABCEF', ncol=2, loc='upper left')
plt.title("Seaborn Plot")
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# ### Seaborn and dataframes:
# <a id='sns2'></a>

# %% [markdown]
# As already mentioned, the seaborn library easily integrates with the functionality of a Pandas `dataframe`. We illustrate this property using historical stock data accessed via `yahoo_finance`.

# %%
import yahoo_fin.stock_info as si
AAPL = si.get_data("AAPL")

# %%
AAPL.tail()
# Out:
#                   open        high         low       close    adjclose  \
# 2021-03-15  121.410004  124.000000  120.419998  123.989998  123.989998
# 2021-03-16  125.699997  127.220001  124.720001  125.570000  125.570000
# 2021-03-17  124.050003  125.860001  122.339996  124.760002  124.760002
# 2021-03-18  122.879997  123.180000  120.320000  120.529999  120.529999
# 2021-03-19  119.900002  121.430000  119.680000  119.989998  119.989998
#
#                  volume ticker
# 2021-03-15   92403800.0   AAPL
# 2021-03-16  114740000.0   AAPL
# 2021-03-17  111437500.0   AAPL
# 2021-03-18  121229700.0   AAPL
# 2021-03-19  185023200.0   AAPL

# %%
ax = AAPL['close'].plot(legend = False)
ax.set_title('Stock history of AAPL')
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# ### Visualising time series
# <a id='sns3'></a>

# %% [markdown]
# Since the historical stock data is clearly a timeseries, it is important to understand how one can handle the different date points of such a dataframe. In fact, Seaborn "understands" the x-lables in a date format ('YYYY-MM-DD'), so we can define plot areas using certain datepoints. This is illustrated by coloring three time periods, were the stock had a local peak by using the method `axvspan`.

# %%
AAPL2 = si.get_data("AAPL", start_date = "01/01/2012")
AAPL2 = AAPL2.dropna()

# %%
plt.style.use('seaborn-deep')
ax = AAPL2["open"].plot(figsize = (10, 5), fontsize=12, linewidth=3, linestyle='--')
ax.set_xlabel('Date', fontsize = 14)
ax.set_ylabel('Value of Apple', fontsize = 14)
ax.set_title("History of Apple stock", fontsize = 14)
ax.axvspan('2018-09-01', '2018-11-01', color='red', alpha=0.3)
ax.axvspan('2020-01-01', '2020-02-01', color='red', alpha=0.3)
ax.axvspan('2020-08-15', '2020-09-15', color='red', alpha=0.3)
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# ### Relation plots:
# <a id='sns4'></a>

# %% [markdown]
# In the statistical analysis of a process it is often very important to understand how differents variables within a dataset relate to each other and how those relationships depend on other variables. Visualization tools can be a core component of this process because, when data are visualized properly, it could be possible to make first assumptions about dependencies, which can then be studied in more detail. A very useful tool provided by Seaborn is the method `relplot()`.

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# The following cells demonstrates how components of the dataset can be highlighted in different ways - e.g. by `color`, `size`, `marker` - such that multiple relationships, trends etc. can be visualised at once.

# %%
sns.relplot(data=tips, x="total_bill", y="tip", col="time",hue="smoker", style="smoker", size="size")
plt.show()

# %%
sns.relplot(data=tips, x="total_bill", y="tip", col="day", row="sex", hue="smoker", style="smoker", size="size")
plt.show()

# %% [markdown]
# In the prior plots, we used a scatter style to identify relationships. However, sometimes it makes more sense to use classical lineplot, especially when the underlying data is a timeseries as follows.

# %%
fmri = sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %% [markdown]
# The following plots illustarte how an initial stimulus of a body part triggers a measurable reaction of the nervous system over time. Note at this point that we have several datapoints for a single x-value (probably because the data was produced in a study with several participants). In this case, the default behavior of Seaborn is to aggregate the multiple measurements at each x-value by additionally plotting a 95%-confidence interval.

# %%
sns.relplot(data=fmri, x="timepoint", y="signal", col="region", hue="event", style="event", kind="line")
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# ### Empirical Histograms and Kernel Density Estimates (KDEs):
# <a id='sns5'></a>

# %% [markdown]
# As we have seen before, plotting histograms gives a first impression about the distribution of the underlying dataset. Based on the basic `matplotlib` functionaliy, `seaborn` adds new features like a kernel density estimate.

# %%
meanVector = [0., 0.]
covMatrix = [[5., 2.], [2., 2.]]
data = np.random.multivariate_normal(meanVector, covMatrix, size = 10000)
data = pd.DataFrame(data, columns = ['x', 'y'])

# %%
for col in 'xy':
    #The parameter alpha defines the opacity of the histgram bars
    plt.hist(data[col], density=True, alpha=0.7, label=col)
plt.legend(loc = 'best')
plt.title('Empirical marginal distributions')
plt.show()

# %% [markdown]
# Different from histograms which use discrete bins, a KDE plot smooths the observations with a Gaussian kernel (by default), producing a continuous density estimate. Some theory on this:

# %% [markdown]
# Let $(x_1, x_2,..., x_n)$ be independent and identically distributed samples drawn from some univariate distribution with an unknown density $f$ at any given point $x$. We are interested in estimating the shape of this function $f$. Its kernel density estimator is
#
# $$
# \hat{f}_h(x) = \frac{1}{nh} \sum_{i=1}^n \mathcal{K}\left(\frac{x-x_i}{h}\right)
# $$
#
#
# where $\mathcal{K}$ is the kernel — a non-negative function — and $h$ > 0 is a smoothing parameter called the bandwidth.

# %%
for col in 'xy':
    sns.kdeplot(data[col], shade=True).set_title("Empirical marginal distributions")

# %% [markdown]
# The Seaborn method `distplot()` can be used to automatically plot the histogram and KDE of a given set of data samples.

# %%
sns.distplot(data['x'], label='x')
sns.distplot(data['y'], label='y')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# ### Visualising correlations
# <a id='sns6'></a>

# %% [markdown]
# Coming back to the important task of analysing dependencies between different variables or samples, we now turn our attention to visualising (empirical) correlations. Again we use historical stock data, to see if we can make first guesses on the relationship of different stock behaviors.

# %%
tickers = ["aapl", "amzn", "ba", "BRK.A", "bac", "V", "baba", "pypl", "xom", "hal", "slb", "csco", "intc", "orcl", "ko", "cl", "pg", "wmt"]
goodtickers = []
df = pd.DataFrame()

for t in tickers:
    try:
        dfTicker = si.get_data(t)
        dfTicker = dfTicker['open']
        df = pd.concat([df, dfTicker], axis=1)
        goodtickers.append(t)
    except:
        print("Ticker ", t, " not available")

df = df.dropna()
df.columns = goodtickers
df.tail(1)
# Out:
# Ticker  BRK.A  not available
#                            aapl        amzn      ba        bac           V  \
# 2021-03-19 00:00:00  119.900002  3029.22998  257.75  38.290001  219.119995
#
#                            baba        pypl        xom        hal    slb  \
# 2021-03-19 00:00:00  239.660004  239.630005  56.709999  22.030001  27.26
#
#                           csco   intc       orcl         ko         cl  \
# 2021-03-19 00:00:00  48.709999  63.18  66.790001  50.459999  76.099998
#
#                              pg         wmt
# 2021-03-19 00:00:00  129.100006  130.130005

# %% [markdown]
# Using the Pandas method `corr()`, we can compute the empirical correlation matrix between the different stock time series.

# %%
corrmat = df.corr(method='pearson')
corrmat
# Out:
#           aapl      amzn        ba       bac         V      baba      pypl  \
# aapl  1.000000  0.946777  0.097051  0.530657  0.876867  0.872320  0.969613
# amzn  0.946777  1.000000  0.291771  0.622105  0.942249  0.922272  0.961596
# ba    0.097051  0.291771  1.000000  0.802335  0.452588  0.406535  0.201253
# bac   0.530657  0.622105  0.802335  1.000000  0.722720  0.731468  0.580127
# V     0.876867  0.942249  0.452588  0.722720  1.000000  0.897503  0.902753
# baba  0.872320  0.922272  0.406535  0.731468  0.897503  1.000000  0.876475
# pypl  0.969613  0.961596  0.201253  0.580127  0.902753  0.876475  1.000000
# xom  -0.861408 -0.828641  0.099521 -0.273416 -0.767880 -0.747385 -0.812499
# hal  -0.699037 -0.721972 -0.059017 -0.221803 -0.780589 -0.591364 -0.707874
# slb  -0.822571 -0.881485 -0.254188 -0.487473 -0.919527 -0.804086 -0.844674
# csco  0.506707  0.699821  0.795991  0.813102  0.809986  0.681108  0.615693
# intc  0.681502  0.792524  0.582113  0.796376  0.879716  0.820074  0.723224
# orcl  0.833473  0.880298  0.485389  0.772997  0.917766  0.890897  0.882094
# ko    0.590548  0.618747  0.499155  0.605351  0.795667  0.624343  0.609715
# cl    0.591005  0.482925 -0.198246  0.148984  0.406180  0.486746  0.560770
# pg    0.866987  0.842940  0.134405  0.467296  0.884776  0.783761  0.853386
# wmt   0.915033  0.945139  0.322737  0.639870  0.956614  0.906044  0.925370
#
#            xom       hal       slb      csco      intc      orcl        ko  \
# aapl -0.861408 -0.699037 -0.822571  0.506707  0.681502  0.833473  0.590548
# amzn -0.828641 -0.721972 -0.881485  0.699821  0.792524  0.880298  0.618747
# ba    0.099521 -0.059017 -0.254188  0.795991  0.582113  0.485389  0.499155
# bac  -0.273416 -0.221803 -0.487473  0.813102  0.796376  0.772997  0.605351
# V    -0.767880 -0.780589 -0.919527  0.809986  0.879716  0.917766  0.795667
# baba -0.747385 -0.591364 -0.804086  0.681108  0.820074  0.890897  0.624343
# pypl -0.812499 -0.707874 -0.844674  0.615693  0.723224  0.882094  0.609715
# xom   1.000000  0.841588  0.880641 -0.343310 -0.567382 -0.642601 -0.455054
# hal   0.841588  1.000000  0.931658 -0.482776 -0.574698 -0.631554 -0.645136
# slb   0.880641  0.931658  1.000000 -0.664816 -0.758730 -0.810555 -0.705910
# csco -0.343310 -0.482776 -0.664816  1.000000  0.833099  0.780248  0.658257
# intc -0.567382 -0.574698 -0.758730  0.833099  1.000000  0.791485  0.653579
# orcl -0.642601 -0.631554 -0.810555  0.780248  0.791485  1.000000  0.749006
# ko   -0.455054 -0.645136 -0.705910  0.658257  0.653579  0.749006  1.000000
# cl   -0.441870 -0.281201 -0.349673  0.105026  0.154381  0.519595  0.406848
# pg   -0.809966 -0.819703 -0.885567  0.557763  0.654341  0.832189  0.782051
# wmt  -0.824423 -0.779572 -0.914757  0.701510  0.795925  0.906918  0.744487
#
#             cl        pg       wmt
# aapl  0.591005  0.866987  0.915033
# amzn  0.482925  0.842940  0.945139
# ba   -0.198246  0.134405  0.322737
# bac   0.148984  0.467296  0.639870
# V     0.406180  0.884776  0.956614
# baba  0.486746  0.783761  0.906044
# pypl  0.560770  0.853386  0.925370
# xom  -0.441870 -0.809966 -0.824423
# hal  -0.281201 -0.819703 -0.779572
# slb  -0.349673 -0.885567 -0.914757
# csco  0.105026  0.557763  0.701510
# intc  0.154381  0.654341  0.795925
# orcl  0.519595  0.832189  0.906918
# ko    0.406848  0.782051  0.744487
# cl    1.000000  0.618968  0.522358
# pg    0.618968  1.000000  0.915122
# wmt   0.522358  0.915122  1.000000

# %% [markdown]
# Since such a matrix can be quite chaotic, if we are only interested in a first impression of dependencies, we can use the Seaborn method `heatmap()` to visualise the different values of the correlation matrix.

# %%
from matplotlib.colors import LinearSegmentedColormap
cmap = LinearSegmentedColormap.from_list('RedGreenRed', ['blue', 'lightblue', 'white', 'orange', 'red'])
sns.heatmap(corrmat, cmap=cmap, vmin=-1., vmax=1., linewidths=.5)
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# ### Visualising data in 2D:
# <a id='sns7'></a>

# %% [markdown]
# Using the function `jointplot()`, it is possible to visualise the distributive properties of two datasets and their dependencies at once.

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data)

# %% [markdown]
# The argument `kind` makes it possible to plot the properties using different methods, like a KDE instead of histogram, or we can add an analysis feature like a linear regression.

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='kde')

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='reg')

# %% [markdown]
# <hr style="border:1.5px solid gray"> </hr>

# %% [markdown]
# ## 5.3. Bokeh
#
# <a id='bokeh'></a>

# %% [markdown]
# Bokeh is a Python library for creating interactive visualizations for modern web browsers. However, it is also possible to create an interactive graphic within a Jupyter Notebook. For more information visit https://docs.bokeh.org/en/latest/index.html.

# %%
import bokeh.plotting
import bokeh.io

# %%
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1262">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# While Bokeh offers quite a huge range of functionalities, we only present the use of widgets to interact with a simple plot of the general sine function given by
#
# $$
# f(x) = a\cdot\sin(k\cdot x + w) + b,
# $$
#
# where $a$ is the parameter for the amplitude, $k$ for the wave frequency, $w$ for the phase and $b$ for the offset.

# %%
import bokeh.plotting.figure as bk_figure
from bokeh.io import curdoc, show
from bokeh.layouts import row, widgetbox
from bokeh.models import ColumnDataSource
from bokeh.models.widgets import Slider, TextInput
from bokeh.io import output_notebook # enables plot interface in Jupyter notebook

from bokeh.application import Application
from bokeh.application.handlers import FunctionHandler

# %% [markdown]
# First, we define the grid for both axes later used for the plot.

# %%
n = 2000
xx = np.linspace(-2.*np.pi, 2.*np.pi, n)
yy = np.sin(xx)
source = ColumnDataSource(data=dict(x=xx, y=yy))

# %% [markdown]
# In the next cell, we use the method `bk_figure()` the define the properties of the function plot. For example, using the argument `tools` allows us to setup a small toolbar next to the plot, which gives us some first interaction points with the graphic.

# %%
plot = bk_figure(plot_height=400, plot_width=400, title="Nik's wave",
              tools="crosshair,pan,reset,save,wheel_zoom",
              x_range=[np.min(xx), np.max(xx)], y_range=[np.min(yy), np.max(yy)])

plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)
# Out:
# GlyphRenderer(id='1299', ...)

# %% [markdown]
# The most important part for the interaction are widgets. They can appear in different forms (e.g. sliders, dropdowns, textinputs). The argument `title` defines which parameter of the plot is changed by using the regarding widgets. Moreover, we need to define helping functions to update the ploted curve, when a widget is used by the user.

# %%
text = TextInput(title="title", value='Sin function')
offset = Slider(title="offset", value=0.0, start=-5.0, end=5.0, step=0.1)
amplitude = Slider(title="amplitude", value=1.0, start=-5.0, end=5.0, step=0.1)
phase = Slider(title="phase", value=0.0, start=0.0, end=2*np.pi)
freq = Slider(title="frequency", value=1.0, start=0.1, end=5.1, step=0.1)

# %%
def update_title(attrname, old, new):
    plot.title.text = text.value

def update_data(attrname, old, new):
    # Get the current slider values
    a = amplitude.value
    b = offset.value
    w = phase.value
    k = freq.value

    # Generate the new curve
    newyy = a*np.sin(k*xx + w) + b

    source.data = dict(x=xx, y=newyy)

for w in [offset, amplitude, phase, freq]:
    w.on_change('value', update_data)

# %% [markdown]
# Finally, we can setup and layout the interactive framework for the plot. In our case, it consists of the function plot itseld, the toolbar and the widgets.

# %%
# Set up layouts and add to document
inputs = widgetbox(text, offset, amplitude, phase, freq)
layout = row(plot, widgetbox(text, offset, amplitude, phase, freq))

def modify_doc(doc):
    doc.add_root(row(layout, width=800))
    doc.title = "Sliders"
    text.on_change('value', update_title)

handler = FunctionHandler(modify_doc)

# %%
show(Application(handler))
# Out:
# <script src="http://localhost:60808/autoload.js?bokeh-autoload-element=1311&bokeh-absolute-url=http://localhost:60808&resources=none" id="1311"></script>

# %% [markdown]
# <hr style="border:1.5px solid gray"> </hr>

# %% [markdown]
# ## 5.4. WordCloud
#
# <a id='wc'></a>

# %% [markdown]
# Lastly, we show another funny way to visualise data using "word clouds" via the library `WordCloud`. In our case, the cloud is filled with the most used words in the titles of new articles about a certain keyword. To access the news articles we use the service of https://newsapi.org, where it is possible to get the content of a huge range of publications within a certain time window.

# %%
from wordcloud import WordCloud

# %% [markdown]
# To access the API, you need a personal key, which you can get for free from https://newsapi.org.

# %%
api = '8491cad2e39a4e5da5b92d24f1cb0eb2'
import requests
import pprint
url = 'https://newsapi.org/v2/everything?'

# %% [markdown]
# Next, you need to define the parameters for your API request. In this case, the parameter `'q'` defines the keyword to search for.

# %%
parameters = {
    'q': 'Musk', # query phrase
    'pageSize': 80,  # maximum is 100
    'apiKey': api, # your own API key
    'from': "2021-02-23"
}
json = requests.get(url, params=parameters).json()
pprint.pprint(json)

for i in json['articles']:
    print(i['title'])
# Out:
# {'articles': [{'author': 'https://www.engadget.com/about/editors/kris-holt',
#                'content': 'Elon Musk\r\n'
#                           ' has added another job title to his portfolio. As '
#                           'if being CEO of multiple companies wasnt enough, '
#                           'hes now Technoking of Tesla for some reason. '
#                           'Meanwhile, the companys CFO, Zach Kirkhorn, … [+773 '
#                           'chars]',
#                'description': 'Watch out, Littlefinger: the automaker’s CFO is '
#                               'now "Master of Coin."',
#                'publishedAt': '2021-03-15T14:22:48Z',
#                'source': {'id': 'engadget', 'name': 'Engadget'},
#                'title': 'Elon Musk changes job title to “Technoking of Tesla”',
#                'url': 'https://www.engadget.com/elon-musk-tesla-technoking-game-of-thrones-master-of-coin-142248051.html',
#                'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/YetUM0YehAPnhW1rUFboFA--~B/aD0zMTUzO3c9NDczMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2021-02/c10c9970-6738-11eb-bf51-9d29cdccec5e.cf.jpg'},
#               {'author': 'Mariella Moon',
#                'content': "For a short while after SpaceX's SN10 Starship "
#                           'touched down, it seemed like the prototype made it '
#                           'out of its test flight unscathed. The vehicle '
#                           'exploded on its landing pad around a minute later, '
#                           'thou… [+1633 chars]',
#                'description': "For a short while after SpaceX's SN10 Starship "
#                               'touched down, it seemed like the prototype made '
#                               'it out of its test flight unscathed. The '
#                               'vehicle exploded on its landing pad around a '
#                               'minute later, though, creating a massive '
#                               'inferno like its predecessorsdid. Now…',
#                'publishedAt': '2021-03-10T07:02:17Z',
#                'source': {'id': 'engadget', 'name': 'Engadget'},
#                'title': 'Elon Musk reveals why the SN10 Starship exploded',
#                'url': 'https://www.engadget.com/sn-10-starship-explosion-elon-musk-070217155.html',
#                'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/IgxwcQfIZ62LYNA.SpVT5Q--~B/aD0zODI7dz02NzU7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2021-03/f4310210-8163-11eb-b7fb-53c47530d5c9.cf.jpg'},
#               {'author': 'Rebecca Bellan',
#                'content': 'Last week, Elon Musk made $25 billion in one day. '
#                           'On Monday, he crowned himself Technoking of Tesla. '
#                           'In Musk-speak, this new title still translates into '
#                           'the Chief Executive Officer of the electric ca… '
#                           '[+1889 chars]',
#                'description': 'Last week, Elon Musk made $25 billion in one '
#                               'day. On Monday, he crowned himself “Technoking '
#                               'of Tesla.” In Musk-speak, this new title still '
#                               'translates into the Chief Executive Officer of '
#                               'the electric car company.\xa0 The eccentric '
#                               'billionaire is nothing if not cr…',
#                'publishedAt': '2021-03-15T14:34:13Z',
#                'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#                'title': 'His Majesty Elon the First, Technoking of Tesla',
#                'url': 'http://techcrunch.com/2021/03/15/his-majesty-elon-the-first-technoking-of-tesla/',
#                'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/01/GettyImages-1229901940.jpg?w=563'},
#               {'author': 'Jay Peters',
#                'content': 'Filed under:\r\n'
#                           'Actually, doesnt feel quite right selling this. '
#                           'Will pass.\r\n'
#                           'Actually, doesnt feel quite right selling this. '
#                           'Will pass.\r\n'
#                           ' Elon Musk (@elonmusk) March 16, 2021\r\n'
#                           'View all 17 stories',
#                'description': 'On Monday, Elon Musk said he was going to sell '
#                               'a techno house song about NFTs as an NFT, but '
#                               'on Tuesday, he backtracked, saying he “doesn’t '
#                               'feel quite right” selling it.',
#                'publishedAt': '2021-03-16T23:55:35Z',
#                'source': {'id': 'the-verge', 'name': 'The Verge'},
#                'title': 'Elon Musk won’t sell his NFT song after all',
#                'url': 'https://www.theverge.com/tldr/2021/3/16/22335019/elon-musk-not-selling-techno-house-nft-song',
#                'urlToImage': 'https://cdn.vox-cdn.com/thumbor/Mn7ieU88U63sskv1P-eowVVY-pA=/0x157:4000x2251/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22376196/1229901655.jpg'},
#               {'author': 'Joey Roulette',
#                'content': 'Yusaku Maezawa announcing his plan to fly on '
#                           'SpaceX’s Starship rocket in September 2018\r\n'
#                           '\n'
#                           ' \n'
#                           '\n'
#                           ' Japanese billionaire Yusaku Maezawa invited the '
#                           'public on Tuesday to apply for a spot on SpaceX’s '
#                           'Starshi… [+2734 chars]',
#                'description': 'Yusaku Maezawa was revealed as Starship’s first '
#                               'signed passenger back in 2018, during an event '
#                               'with Elon Musk at SpaceX’s California '
#                               'headquarters.',
#                'publishedAt': '2021-03-02T22:18:42Z',
#                'source': {'id': 'the-verge', 'name': 'The Verge'},
#                'title': 'Japanese billionaire is looking for eight people to '
#                         'join him for a Moon voyage on SpaceX rocket',
#                'url': 'https://www.theverge.com/2021/3/2/22309546/japanese-billionaire-maezawa-dear-moon-spacex',
#                'urlToImage': 'https://cdn.vox-cdn.com/thumbor/EbAD5VynWyNroxJbr-SjKWWO_CU=/0x53:4000x2147/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22340405/1035243908.jpg'},
#               {'author': 'Aria Alamalhodaei',
#                'content': 'Tesla CEO Elon Musk’s tweets are the subject of '
#                           'another lawsuit.\r\n'
#                           'A Tesla investor is suing the company board and '
#                           'Musk for continuing to send ‘erratic tweets’ that '
#                           'violate a settlement with the U.S. … [+3397 chars]',
#                'description': 'Tesla CEO Elon Musk’s tweets are the subject of '
#                               'another lawsuit. A Tesla investor is suing the '
#                               'company board and Musk for continuing to send '
#                               '‘erratic tweets’ that violate a settlement with '
#                               'the U.S. Securities and Exchange Commission '
#                               'that requires oversight of…',
#                'publishedAt': '2021-03-12T21:18:15Z',
#                'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#                'title': 'Elon Musk, Tesla board sued in lawsuit alleging '
#                         '“erratic” tweets violate fiduciary duty',
#                'url': 'http://techcrunch.com/2021/03/12/elon-musk-tesla-board-sued-in-lawsuit-alleging-erratic-tweets-violate-fiduciary-duty/',
#                'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/02/GettyImages-1175368064.jpg?w=600'},
#               {'author': 'Kim Lyons',
#                'content': 'Illustration by Alex Castro / The Verge\r\n'
#                           '\n'
#                           ' \n'
#                           '\n'
#                           ' Tesla is expanding its “Full Self-Driving” (FSD) '
#                           'beta, CEO Elon Musk said, doubling its size with a '
#                           'new software update, and eventually increasing the '
#                           'nu… [+1444 chars]',
#                'description': 'Tesla is expanding the “Full Self-Driving” '
#                               '(FSD) beta it launched in October, according to '
#                               'CEO Elon Musk. Tesla plans to double the size '
#                               'of the beta test pool and eventually increase '
#                               'the number of vehicles in the beta tenfold.',
#                'publishedAt': '2021-03-07T17:10:28Z',
#                'source': {'id': 'the-verge', 'name': 'The Verge'},
#                'title': 'Elon Musk says Tesla is expanding its Full Self '
#                         'Driving beta to more drivers',
#                'url': 'https://www.theverge.com/2021/3/7/22318155/elon-musk-tesla-expanding-full-self-driving-beta',
#                'urlToImage': 'https://cdn.vox-cdn.com/thumbor/QOXVhSBb4175xx8o0uvdkZ4tAgA=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/11423503/acastro_180524_1777_tesla_0001.jpg'},
#               {'author': 'Sam Blum',
#                'content': 'Newly minted worlds richest man Elon Musk has a new '
#                           'job title befitting his wealth. Though his empire '
#                           'spans multiple industries, hes ridding himself of '
#                           'the CEO moniker at only one of the companies un… '
#                           '[+3567 chars]',
#                'description': 'Newly minted world’s richest man Elon Musk has '
#                               'a new job title befitting his wealth. Though '
#                               'his empire spans multiple industries, he’s '
#                               'ridding himself of the CEO moniker at only one '
#                               'of the companies under his thumb, opting for '
#                               'the title of “Technoking” at the…',
#                'publishedAt': '2021-03-15T21:00:00Z',
#                'source': {'id': None, 'name': 'Lifehacker.com'},
#                'title': 'Your Job Title Is Meaningless, So Share This Instead',
#                'url': 'https://lifehacker.com/your-job-title-is-meaningless-so-share-this-instead-1846480155',
#                'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/orqkb3sffakbcfdgwucz.jpg'},
#               {'author': 'Chris Isidore, CNN Business',
#                'content': None,
#                'description': 'Elon Musk is not your typical CEO. Now he has a '
#                               'new title to prove it.',
#                'publishedAt': '2021-03-15T11:56:52Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': "Elon Musk has a new title at Tesla. He's the "
#                         "'Technoking'",
#                'url': 'https://www.cnn.com/2021/03/15/investing/elon-musk-technoking-of-tesla/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210315073602-elon-musk-file-201201-super-tease.jpg'},
#               {'author': 'Shoshana Wodinsky',
#                'content': 'Elon Musks tweets have landed him in hot water with '
#                           'shareholdersagain. This time, he and the Tesla '
#                           'board are staring down a suit from one disgruntled '
#                           'investor who claims some of the CEOs tweets viola… '
#                           '[+1852 chars]',
#                'description': 'Elon Musk’s tweets have landed him in hot water '
#                               'with shareholders—again. This time, he and the '
#                               'Tesla board are staring down a suit from one '
#                               'disgruntled investor who claims some of the '
#                               'CEO’s tweets violate a 2019 settlement Musk had '
#                               'reached with the Securities…',
#                'publishedAt': '2021-03-13T00:30:00Z',
#                'source': {'id': None, 'name': 'Gizmodo.com'},
#                'title': "Elon Musk's Awful Tweets Are the Subject of Yet "
#                         'Another Lawsuit',
#                'url': 'https://gizmodo.com/elon-musks-awful-tweets-are-the-subject-of-yet-another-1846467919',
#                'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/s89wzscxrfdaknhuobdo.jpg'},
#               {'author': 'Igor Bonifacic',
#                'content': 'Tesla is building a secret energy storage project '
#                           'in Texas, according to Bloomberg\r\n'
#                           '. In Angleton, a town of nearly 20,000 located 40 '
#                           'miles south of Houston, Tesla subsidiary Gambit '
#                           'Energy Storage is… [+1137 chars]',
#                'description': 'Tesla is building a secret energy storage '
#                               'project in Texas, according to Bloomberg\r\n'
#                               '. In Angleton, a town of nearly 20,000 located '
#                               '40 miles south of Houston, Tesla subsidiary '
#                               'Gambit Energy Storage is installing the '
#                               'company’s modular Megapacks\r\n'
#                               '. When complete…',
#                'publishedAt': '2021-03-08T20:43:29Z',
#                'source': {'id': 'engadget', 'name': 'Engadget'},
#                'title': 'Tesla is building a secret 100MW energy storage '
#                         'project in Texas',
#                'url': 'https://www.engadget.com/tesla-battery-farm-angelton-texas-204329254.html',
#                'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/XuPSsmZoE3ioyUh0yhuaqw--~B/aD0xMDAwO3c9MTYwMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2021-03/9fd510b0-804d-11eb-9df7-44401a3d6a7e.cf.jpg'},
#               {'author': 'Sam Blum',
#                'content': 'There might be no better representation of failure '
#                           'than when a project youve been working on explodes '
#                           'spectacularly in front of an audience of thousands. '
#                           'When SpaceX CEO Elon Musk does itlike his com… '
#                           '[+5592 chars]',
#                'description': 'There might be no better representation of '
#                               'failure than when a project you’ve been working '
#                               'on explodes spectacularly in front of an '
#                               'audience of thousands. When SpaceX CEO Elon '
#                               'Musk does it—like his company arguably did at '
#                               'the very tail end of its Starship pro…',
#                'publishedAt': '2021-03-05T19:30:00Z',
#                'source': {'id': None, 'name': 'Lifehacker.com'},
#                'title': 'How to Find Success Within Your Failures',
#                'url': 'https://lifehacker.com/how-to-find-success-within-your-failures-1846415288',
#                'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/v2vwwzbqzw5svhifbb89.png'},
#               {'author': 'Adam Rosenberg',
#                'content': 'Elon Musk skipped his preferred platform of Twitter '
#                           'for this latest round of corporate diplomacy, so '
#                           "you know he's serious.\r\n"
#                           'Musk spoke up over the weekend after a Friday '
#                           'report from the Wall Street … [+2447 chars]',
#                'description': 'Elon Musk skipped his preferred platform of '
#                               'Twitter for this latest round of corporate '
#                               "diplomacy, so you know he's serious.\n"
#                               'Musk spoke up over the weekend after a Friday '
#                               'report from the Wall Street Journal revealed '
#                               'that China would bar "military staff and emp…',
#                'publishedAt': '2021-03-21T16:38:50Z',
#                'source': {'id': 'mashable', 'name': 'Mashable'},
#                'title': 'Elon Musk explains why Tesla would never share data '
#                         'with China *or* the U.S.',
#                'url': 'https://mashable.com/article/elon-musk-tesla-china-sharing-data/',
#                'urlToImage': 'https://mondrian.mashable.com/2021%252F03%252F21%252F89%252F9f7942aa0441411c9271c46872619260.d72d7.jpg%252F1200x630.jpg?signature=0chz3FMszTqn5Gc6BUFXN2vXgrk='},
#               {'author': 'Darrell Etherington',
#                'content': 'SpaceX’s grand vision for Starship, the '
#                           'next-generation spacecraft it’s currently in the '
#                           'process of developing, includes not only trips to '
#                           'Mars, but also regular point-to-point flights right '
#                           'here on … [+1751 chars]',
#                'description': 'SpaceX’s grand vision for Starship, the '
#                               'next-generation spacecraft it’s currently in '
#                               'the process of developing, includes not only '
#                               'trips to Mars, but also regular point-to-point '
#                               'flights right here on Earth. These would skim '
#                               'the Earth’s outer atmosphere, reduci…',
#                'publishedAt': '2021-02-24T17:35:56Z',
#                'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#                'title': 'SpaceX’s floating oil rig spaceship launch pad could '
#                         'be operating later this year according to Elon Musk',
#                'url': 'http://techcrunch.com/2021/02/24/spacexs-floating-oil-rig-spaceship-launch-pad-could-be-operating-later-this-year-according-to-elon-musk/',
#                'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/02/starship-landing-pad.jpg?w=764'},
#               {'author': 'Darrell Etherington',
#                'content': 'SpaceX has completed what’s known as the ‘stacking’ '
#                           'of its first Super Heavy prototype, the extremely '
#                           'large next-generation first-stage rocket booster '
#                           'that it will eventually use to propel its Starsh… '
#                           '[+1930 chars]',
#                'description': 'SpaceX has completed what’s known as the '
#                               '‘stacking’ of its first Super Heavy prototype, '
#                               'the extremely large next-generation first-stage '
#                               'rocket booster that it will eventually use to '
#                               'propel its Starship spacecraft to orbit and '
#                               'beyond. The Super Heavy Booster i…',
#                'publishedAt': '2021-03-19T14:16:45Z',
#                'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#                'title': 'SpaceX nears final assembly of its first massive '
#                         'testing rocket booster for Starship',
#                'url': 'http://techcrunch.com/2021/03/19/spacex-nears-final-assembly-of-its-first-massive-testing-rocket-booster-for-starship/',
#                'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/03/super-heavy-booster.jpeg?w=479'},
#               {'author': 'Stan Schroeder',
#                'content': 'Elon Musk, Technoking of Tesla, EDM music producer, '
#                           'lover of Doge, fashionista, and prankster, is '
#                           'making music again.\xa0\r\n'
#                           'On Monday, he posted a techno music track on '
#                           "Twitter, claiming he's selling it … [+1496 chars]",
#                'description': 'Elon Musk, Technoking of Tesla, EDM music '
#                               'producer, lover of Doge, fashionista, and '
#                               'prankster, is making music again.\xa0\n'
#                               'On Monday, he posted a techno music track on '
#                               "Twitter, claiming he's selling it as an NFT. "
#                               'Check it out below.\xa0\n'
#                               '\n'
#                               '\n'
#                               '\r\n'
#                               '\n'
#                               '\r\n'
#                               '\n'
#                               'NFTs, or non-fungible…',
#                'publishedAt': '2021-03-16T08:12:58Z',
#                'source': {'id': 'mashable', 'name': 'Mashable'},
#                'title': "Elon Musk made a song about NFTs, and he's selling it "
#                         'as an NFT',
#                'url': 'https://mashable.com/article/elon-musk-nft-song/',
#                'urlToImage': 'https://mondrian.mashable.com/2021%252F03%252F16%252Fb4%252F7a30374676ab4bc9aed0b8dd99fd0837.1ddf5.jpg%252F1200x630.jpg?signature=N16DxWMos7Im_9qu56Le3S8QTlU='},
#               {'author': "Danica D'Souza",
#                'content': "Mashable's Jennimai Nguyen\r\n"
#                           " answers the most pressing questions about SpaceX's "
#                           'internet system, how it all really works, and how '
#                           'to sign up.',
#                'description': "Mashable's Jennimai Nguyen\r\n"
#                               ' answers the most pressing questions about '
#                               "SpaceX's internet system, how it all really "
#                               'works, and how to sign up. Read more...More '
#                               'about Mashable Video, Elon Musk, Spacex, '
#                               'Starlink, and Satellite Internet',
#                'publishedAt': '2021-03-19T21:33:38Z',
#                'source': {'id': 'mashable', 'name': 'Mashable'},
#                'title': 'What is Starlink? Elon Musk’s satellite internet '
#                         'service explained',
#                'url': 'https://mashable.com/video/starlink-elon-musk-space-x-internet-explainer/',
#                'urlToImage': 'https://mondrian.mashable.com/2021%252F03%252F19%252Fd0%252F6ca8f18b2dfb44ecb2f9c08e368b5a4a.de528.png%252F1200x630.png?signature=hPAXEhqJwtVbNnBRA-O7KVdTeJ4='},
#               {'author': 'Aria Alamalhodaei',
#                'content': 'Elon Musk is bringing his utility-scale battery '
#                           'ambitions to the Lone Star state.\xa0\r\n'
#                           'An under-the-radar Tesla subsidiary has been at '
#                           'work building a 100 MW energy storage project in '
#                           'Angleton, Texas, a… [+1447 chars]',
#                'description': 'Elon Musk is bringing his utility-scale battery '
#                               'ambitions to the Lone Star state.\xa0 An '
#                               'under-the-radar Tesla subsidiary has been at '
#                               'work building a 100 MW energy storage project '
#                               'in Angleton, Texas, according to an application '
#                               'with the Public Utilities Commissi…',
#                'publishedAt': '2021-03-08T16:22:04Z',
#                'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#                'title': 'Tesla’s utility-scale batteries are coming to Texas',
#                'url': 'http://techcrunch.com/2021/03/08/teslas-utility-scale-batteries-are-coming-to-texas/',
#                'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/03/GettyImages-980337816.jpg?w=600'},
#               {'author': 'Tom Knowles, Technology Correspondent',
#                'content': 'When Elon Musk gave his son the improbable and '
#                           'baffling name X Æ A-12, Wall Street must have known '
#                           'it was only a matter of time before he turned his '
#                           'attention to company titles.\r\n'
#                           'Now the Securities a… [+522 chars]',
#                'description': '<ol><li>Tesla founder Elon Musk crowns himself '
#                               'TechnoKing | News\xa0\xa0The Times\r\n'
#                               '</li><li>Elon Musk changes job title to '
#                               "'Technoking of Tesla'\xa0\xa0BBC News\r\n"
#                               '</li><li>Elon Musk is The Technoking (HBO Max '
#                               'Ads, Tinder Background Check)\xa0\xa0MUO\r\n'
#                               "</li><li>Elon Musk 'Technok…",
#                'publishedAt': '2021-03-16T00:01:00Z',
#                'source': {'id': None, 'name': 'The Times'},
#                'title': 'Tesla founder Elon Musk crowns himself TechnoKing | '
#                         'News - The Times',
#                'url': 'https://www.thetimes.co.uk/article/tesla-founder-elon-musk-crowns-himself-technoking-v7t3rpgnz',
#                'urlToImage': 'https://www.thetimes.co.uk/imageserver/image/%2Fmethode%2Ftimes%2Fprod%2Fweb%2Fbin%2Ffd123d76-85b0-11eb-89d7-285b40446405.jpg?crop=4251%2C2391%2C0%2C0&resize=685'},
#               {'author': 'Tom McKay',
#                'content': 'If you want a picture of the future of art, imagine '
#                           'a boot stamping on a human faceforever.\r\n'
#                           'Elon Musks abomination of a non-fungible token '
#                           '(NFT) is selling for over one million dollars, not '
#                           'quite pr… [+2615 chars]',
#                'description': 'If you want a picture of the future of art, '
#                               'imagine a boot stamping on a human '
#                               'face—forever.Read more...',
#                'publishedAt': '2021-03-16T18:50:00Z',
#                'source': {'id': None, 'name': 'Gizmodo.com'},
#                'title': "Elon's Doing Another Bit",
#                'url': 'https://gizmodo.com/elons-doing-another-bit-1846487147',
#                'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/klvmlzeqt5epttgiqzj7.png'},
#               {'author': 'Eric Berger',
#                'content': 'Enlarge/ Starship SN10 on the pad on Wednesday, '
#                           'March 3, 2021.\r\n'
#                           '4 with 4 posters participating, including story '
#                           'author\r\n'
#                           'SpaceX may launch its third full-scale Starship '
#                           'prototypenamed Serial Number 10… [+3184 chars]',
#                'description': 'Musk says he is confident Starship will be '
#                               'ready for a lunar flight in three years.',
#                'publishedAt': '2021-03-03T13:12:49Z',
#                'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#                'title': 'SpaceX set for its third major Starship flight test '
#                         'on Wednesday',
#                'url': 'https://arstechnica.com/science/2021/03/spacex-set-for-its-third-major-starship-flight-test-on-wednesday/',
#                'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2021/03/SN10-Mar-3-2021-1-760x380.jpg'},
#               {'author': 'Stephanie Mlot',
#                'content': 'March\r\n'
#                           '16, 2021\r\n'
#                           '2 min read\r\n'
#                           'This story originally appeared on PCMagSpaceX broke '
#                           'its own record on Sunday when it sent a Falcon 9 '
#                           'rocket into space for the ninth time. The '
#                           'successful launch and landi… [+1754 chars]',
#                'description': 'Elon Musk celebrates another reusable rocket '
#                               'win on Sunday.',
#                'publishedAt': '2021-03-16T14:30:00Z',
#                'source': {'id': None, 'name': 'PCMag.com'},
#                'title': 'SpaceX Breaks Its Own Falcon 9 Flight Record During '
#                         'Starlink Launch',
#                'url': 'https://www.pcmag.com/news/spacex-breaks-its-own-falcon-9-flight-record-during-starlink-launch',
#                'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1615902277-SpaceX.jpg'},
#               {'author': 'Julia Musto',
#                'content': 'Billionaire Elon Musk reversed course on Tuesday '
#                           'after announcing he would sell a\xa0techno music '
#                           'track he produced about\xa0non-fungible tokens\xa0'
#                           '(NFT).\r\n'
#                           'The Tesla and SpaceX founder, who recently declared '
#                           '… [+1595 chars]',
#                'description': '<ol><li>Elon Musk reverses course on selling '
#                               'NFT song\xa0\xa0Fox Business\r\n'
#                               '</li><li>Elon Musk turns down $1 million offer '
#                               'to buy his tweet as an NFT\xa0\xa0CNBC\r\n'
#                               '</li><li>Elon Musk Passes On $1 Million USD '
#                               'Offer for His Tweet as an NFT\xa0\xa0'
#                               'HYPEBEAST\r\n'
#                               "</li><li>Tesla's (TSLA)…",
#                'publishedAt': '2021-03-17T13:27:02Z',
#                'source': {'id': None, 'name': 'Fox Business'},
#                'title': 'Elon Musk reverses course on selling NFT song - Fox '
#                         'Business',
#                'url': 'https://www.foxbusiness.com/technology/elon-musk-reverses-course-selling-nft-song',
#                'urlToImage': 'https://a57.foxnews.com/static.foxbusiness.com/foxbusiness.com/content/uploads/2021/02/0/0/Elon-Musk.jpg?ve=1&tl=1'},
#               {'author': 'Paul R. La Monica, CNN Business',
#                'content': "New York (CNN Business)Bitcoin's roller coaster "
#                           'ride continues. The top cryptocurrency surged to a '
#                           'new all-time high above $58,000 on Sunday but fell '
#                           'to just above $46,000 in early trading Tuesday mo… '
#                           '[+2159 chars]',
#                'description': "Bitcoin's roller coaster ride continues. The "
#                               'top cryptocurrency surged to a new all-time '
#                               'high above $58,000 on Sunday but fell to just '
#                               'above $46,000 in early trading Tuesday morning.',
#                'publishedAt': '2021-02-23T14:50:21Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Elon Musk, Bill Gates and Janet Yellen are sending '
#                         'bitcoin tumbling',
#                'url': 'https://www.cnn.com/2021/02/23/investing/bitcoin-prices-fall-yellen-gates/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210222084328-03-bitcoin-file-super-tease.jpg'},
#               {'author': 'Reuters Editorial',
#                'content': 'Posted \r\n'
#                           'Tesla CEO Elon Musk and the board of the electric '
#                           'car company have been sued by a shareholder who '
#                           'accused Musk of violating his 2018 settlement with '
#                           'the U.S. Securities and Exchange Commissi… [+50 '
#                           'chars]',
#                'description': 'Tesla CEO Elon Musk and the board of the '
#                               'electric car company have been sued by a '
#                               'shareholder who accused Musk of violating his '
#                               '2018 settlement with the U.S. Securities and '
#                               'Exchange Commission over his Twitter use.  '
#                               'Conway G. Gittens reports.',
#                'publishedAt': '2021-03-12T22:01:15Z',
#                'source': {'id': 'reuters', 'name': 'Reuters'},
#                'title': 'Tesla investor sues Musk, board over tweets - Reuters',
#                'url': 'https://www.reuters.com/video/watch/idOVE3S91MZ',
#                'urlToImage': 'https://static.reuters.com/resources/r/?d=20210312&i=OVE3S91MZ&r=OVE3S91MZ&t=2'},
#               {'author': 'Richard Lawler',
#                'content': 'Japanese fashion billionaire Yusaku Maezawa '
#                           "purchased the right to be SpaceX's first lunar "
#                           "tourist on a mission that's scheduled for 2023, but "
#                           "he won't be going alone. Maezawa bought all the "
#                           'seats on… [+1016 chars]',
#                'description': 'Japanese fashion billionaire Yusaku Maezawa '
#                               "purchased the right to be SpaceX's first lunar "
#                               "tourist on a mission that's scheduled for 2023, "
#                               "but he won't be going alone. Maezawa bought all "
#                               'the seats on the flight, and announced plans to '
#                               'choose eight people to t…',
#                'publishedAt': '2021-03-03T04:39:40Z',
#                'source': {'id': 'engadget', 'name': 'Engadget'},
#                'title': "SpaceX's first lunar tourist is looking for eight "
#                         'crew members',
#                'url': 'https://www.engadget.com/yusaku-maezawa-open-invite-to-the-moon-043940638.html',
#                'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/ZRMKoVJ9VvD5lwPL89HNew--~B/aD0yMjYxO3c9MzQwMTthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2021-03/0516cf40-7bda-11eb-bedf-fd2171b20c9f.cf.jpg'},
#               {'author': 'Darrell Etherington',
#                'content': 'SpaceX hasn’t issue any public statement about the '
#                           '$850 million in fresh funding CNBC reported it '
#                           'raised last week, but a filing with the U.S. '
#                           'Securities and Exchange Commission (SEC) published '
#                           'today… [+2494 chars]',
#                'description': 'SpaceX hasn’t issue any public statement about '
#                               'the $850 million in fresh funding CNBC reported '
#                               'it raised last week, but a filing with the U.S. '
#                               'Securities and Exchange Commission (SEC) '
#                               'published today confirms the round. SpaceX’s '
#                               'funding was said to value the …',
#                'publishedAt': '2021-02-23T22:01:09Z',
#                'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#                'title': 'SpaceX’s new $850 million raise confirmed in SEC '
#                         'filing',
#                'url': 'http://techcrunch.com/2021/02/23/spacexs-new-850-million-raise-confirmed-in-sec-filing/',
#                'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/06/GettyImages-1216515625-1.jpg?w=678'},
#               {'author': 'Timothy B. Lee',
#                'content': 'Enlarge/ Then-future Technoking Elon Musk enjoying '
#                           "some cannabis on Joe Rogan's podcast.\r\n"
#                           '13 with 13 posters participating\r\n'
#                           "Tesla CEO Elon Musk is now Tesla's Technoking, the "
#                           'company said in an offic… [+1484 chars]',
#                'description': 'Tesla CFO Zach Kirkhorn is now "Master of '
#                               'Coin," Tesla says in SEC filing.',
#                'publishedAt': '2021-03-15T14:42:02Z',
#                'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#                'title': 'Elon Musk formally declares himself Technoking of '
#                         'Tesla',
#                'url': 'https://arstechnica.com/cars/2021/03/elon-musk-formally-declares-himself-technoking-of-tesla/',
#                'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2018/09/elon_musk-760x380.png'},
#               {'author': 'Reuters',
#                'content': 'By Jonathan Stempel\r\n'
#                           '(Reuters) - Tesla (NASDAQ:TSLA) Inc Chief Executive '
#                           'Elon Musk has been sued by a shareholder who '
#                           'accused him of violating his 2018 settlement with '
#                           'the U.S. Securities and Exchang… [+2062 chars]',
#                'description': '<ol><li>Tesla investor sues Musk, says many '
#                               'tweets in violation of SEC settlement By '
#                               'Reuters\xa0\xa0Investing.com\r\n'
#                               '</li><li>Tesla investor sues Musk, claims '
#                               'tweets violate SEC settlement\xa0\xa0Yahoo '
#                               'Finance UK\r\n'
#                               '</li><li>Pros and Cons of LFP Batteries as Musk '
#                               'Shifts Some…',
#                'publishedAt': '2021-03-12T18:45:00Z',
#                'source': {'id': None, 'name': 'Investing.com'},
#                'title': 'Tesla investor sues Musk, says many tweets in '
#                         'violation of SEC settlement By Reuters - '
#                         'Investing.com',
#                'url': 'https://www.investing.com/news/technology-news/tesla-investor-sues-musk-says-many-tweets-in-violation-of-sec-settlement-2445520',
#                'urlToImage': 'https://i-invdn-com.akamaized.net/news/LYNXMPEA7O0P0_L.jpg'},
#               {'author': 'Reuters Staff',
#                'content': 'By Reuters Staff\r\n'
#                           'BEIJING, March 20 (Reuters) - Tesla Inc chief '
#                           'executive Elon Musk said on Saturday it would be '
#                           'good for the United States and China to have more '
#                           'trust in each other.\r\n'
#                           'Musk was holdi… [+374 chars]',
#                'description': 'Tesla Inc chief executive Elon Musk said on '
#                               'Saturday it would be good for the United States '
#                               'and China to have more trust in each other.',
#                'publishedAt': '2021-03-20T03:52:00Z',
#                'source': {'id': 'reuters', 'name': 'Reuters'},
#                'title': 'Musk says would be good for U.S., China to increase '
#                         'mutual trust - Reuters',
#                'url': 'https://www.reuters.com/article/china-forum-musk-idUSB9N2G700Q',
#                'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800'},
#               {'author': 'Reuters Editorial',
#                'content': 'Posted \r\n'
#                           'Tesla has officially listed founder Elon Musk as '
#                           "its 'technoking' in a regulatory filing, while the "
#                           "firm's financial chief is named 'master of coin'. "
#                           'There was no explanation of the cryptic … [+10 '
#                           'chars]',
#                'description': 'Tesla has officially listed founder Elon Musk '
#                               "as its 'technoking' in a regulatory filing, "
#                               "while the firm's financial chief is named "
#                               "'master of coin'. There was no explanation of "
#                               'the cryptic new titles.',
#                'publishedAt': '2021-03-15T14:31:28Z',
#                'source': {'id': 'reuters', 'name': 'Reuters'},
#                'title': "Elon Musk gets a new title: 'Technoking of Tesla' - "
#                         'Reuters',
#                'url': 'https://www.reuters.com/video/watch/idPR$N?now=true',
#                'urlToImage': 'https://ajo.prod.reuters.tv/api/v2/img/604f67fee4b0653eea18495b-1615816702553?location=LANDSCAPE'},
#               {'author': 'Reuters Staff',
#                'content': 'By Reuters Staff\r\n'
#                           'FILE PHOTO: SpaceX owner and Tesla CEO Elon Musk '
#                           'speaks during a conversation with legendary game '
#                           'designer Todd Howard (not pictured) at the E3 '
#                           'gaming convention in Los Angeles, Cal… [+916 chars]',
#                'description': 'Tesla Inc added "Technoking of Tesla" to '
#                               "billionaire Chief Executive Elon Musk's list of "
#                               'official titles on Monday in a formal '
#                               'regulatory filing that also named finance chief '
#                               'Zachary Kirkhorn "Master of Coin".',
#                'publishedAt': '2021-03-15T11:28:00Z',
#                'source': {'id': 'reuters', 'name': 'Reuters'},
#                'title': "Tesla names Musk 'Technoking' in cryptic regulatory "
#                         'filing - Reuters',
#                'url': 'https://www.reuters.com/article/us-tesla-musk-idUSKBN2B71AX',
#                'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210315&t=2&i=1554928077&r=LYNXMPEH2E0UD&w=800'},
#               {'author': 'Entrepreneur en Español',
#                'content': 'This article was translated from our Spanish '
#                           'edition using AI technologies. Errors may exist due '
#                           'to this process.\r\n'
#                           'Do you remember baby X Æ A-Xii ? This is how Elon '
#                           "Musk's little son has grown upand … [+911 chars]",
#                'description': 'Everything seems to indicate that they were on '
#                               'the land where he plans to build a new city.',
#                'publishedAt': '2021-03-09T19:17:42Z',
#                'source': {'id': None, 'name': 'Entrepreneur'},
#                'title': 'Elon Musk shares family photo from Starbase',
#                'url': 'https://www.entrepreneur.com/article/366808',
#                'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1615317407-Elon-Musk-Familia.jpg'},
#               {'author': 'Reuters Staff',
#                'content': 'By Reuters Staff\r\n'
#                           'FILE PHOTO: CEO of Tesla Motors Elon Musk reacts '
#                           "following the company's initial public offering at "
#                           'the NASDAQ market in New York June 29, 2010. '
#                           'REUTERS/Brendan McDermid//File Photo… [+480 chars]',
#                'description': 'Tesla Inc chief executive Elon Musk said on '
#                               'Saturday it would be good for the United States '
#                               'and China to have more trust in each other.',
#                'publishedAt': '2021-03-20T04:03:00Z',
#                'source': {'id': 'reuters', 'name': 'Reuters'},
#                'title': 'Musk says would be good for U.S., China to increase '
#                         'mutual trust - Reuters',
#                'url': 'https://www.reuters.com/article/us-china-forum-musk-idUSKBN2BC04Q',
#                'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210320&t=2&i=1555556446&r=LYNXMPEH2J01L&w=800'},
#               {'author': 'Michelle Jones',
#                'content': 'March\r\n'
#                           '15, 2021\r\n'
#                           '3 min read\r\n'
#                           'This story originally appeared on ValueWalkTesla '
#                           'has given CEO Elon Musk a new title: “Technoking.” '
#                           'A\xa0filing\xa0with the Securities and Exchange '
#                           'Commission revealed Tesla’s … [+2394 chars]',
#                'description': 'Electric automaker Tesla gives CEO Elon Musk '
#                               "the new title of 'Technoking'.",
#                'publishedAt': '2021-03-15T16:19:10Z',
#                'source': {'id': None, 'name': 'ValueWalk'},
#                'title': "Elon Musk's Title Changed to 'Technoking Of Tesla'",
#                'url': 'https://www.valuewalk.com/elon-musk-title-changed-technoking-tesla',
#                'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1615825090-elon-musk.jpg'},
#               {'author': "Tim O'Reilly",
#                'content': 'High-profile entrepreneurs like Elon Musk, venture '
#                           'capitalists like Peter Thiel and Keith Rabois, and '
#                           'big companies like Oracle and HP Enterprise are all '
#                           'leaving California. During Covid-19, Zoom-ena… '
#                           '[+4039 chars]',
#                'description': 'The next entrepreneurial revolution will arise '
#                               'to combat the crisis of our lifetime.',
#                'publishedAt': '2021-03-08T14:13:13Z',
#                'source': {'id': 'wired', 'name': 'Wired'},
#                'title': 'Climate Change Will Reshape Silicon Valley As We Know '
#                         'It',
#                'url': 'https://www.wired.com/story/climate-change-silicon-valley/',
#                'urlToImage': 'https://media.wired.com/photos/604015bbedc8f363fb9c7f8a/191:100/w_1280,c_limit/OpEd-Reshape-Climate-Tech-587183344.jpg'},
#               {'author': 'Reuters Staff',
#                'content': 'By Reuters Staff\r\n'
#                           'FILE PHOTO: SpaceX owner and Tesla CEO Elon Musk '
#                           'speaks at the E3 gaming convention in Los Angeles, '
#                           'California, U.S., June 13, 2019. REUTERS/Mike '
#                           'Blake\r\n'
#                           '(Reuters) - Billionaire entr… [+801 chars]',
#                'description': 'Billionaire entrepreneur Elon Musk will '
#                               'construct a large battery that will connect to '
#                               'the Texas grid, Bloomberg News reported on '
#                               'Monday.',
#                'publishedAt': '2021-03-08T12:32:00Z',
#                'source': {'id': 'reuters', 'name': 'Reuters'},
#                'title': 'Tesla to build large battery for Texas grid: '
#                         'Bloomberg News - Reuters',
#                'url': 'https://www.reuters.com/article/us-musk-texas-idUSKBN2B019J',
#                'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210308&t=2&i=1554131310&r=LYNXMPEH270T4&w=800'},
#               {'author': 'James Murphy',
#                'content': 'Opinions expressed by Entrepreneur contributors are '
#                           'their own.\r\n'
#                           'Over a month ago Tesla announced it had purchased '
#                           '$1.5 billion in Bitcoin, representing 10% of the '
#                           'company’s cash reserve. In the same … [+4811 chars]',
#                'description': 'As with everything Elon Musk does, the answer '
#                               'lies somewhere in the murky middle...',
#                'publishedAt': '2021-03-09T11:30:00Z',
#                'source': {'id': None, 'name': 'Entrepreneur'},
#                'title': "Is Tesla's Bitcoin Gambit Genius or Madness?",
#                'url': 'https://www.entrepreneur.com/article/365515',
#                'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1615230992-GettyImages-1229901624-edit.jpg'},
#               {'author': 'PCMag',
#                'content': 'Tesla knows how to manufacture massive batteries, '
#                           "just ask Australia. Now it's producing another one "
#                           'as a backup for Texas.\r\n'
#                           'As Bloomberg reports, Gambit Energy Storage LLC is '
#                           'a registered subsidiary… [+1450 chars]',
#                'description': 'Tesla knows how to manufacture massive '
#                               "batteries, just ask Australia. Now it's "
# ...
#                'content': 'Tesla, en estos momentos, es una compañía referente '
#                           'en el mundo de la automoción eléctrica. Mientras '
#                           'que los fabricantes convencionales pivotan hacia '
#                           'esta nueva realidad, la empresa de Elon Musk ha e… '
#                           '[+1972 chars]',
#                'description': 'Tesla, en estos momentos, es una compañía '
#                               'referente en el mundo de la automoción '
#                               'eléctrica. Mientras que los fabricantes '
#                               'convencionales pivotan hacia esta nueva '
#                               'realidad, la empresa de Elon Musk ha estado '
#                               'preparándose para este momento durante años, '
#                               'obteniend…',
#                'publishedAt': '2021-03-01T10:39:34Z',
#                'source': {'id': None, 'name': 'Hipertextual'},
#                'title': 'Elon Musk revela cuál es el mayor reto al que se '
#                         'enfrenta Tesla',
#                'url': 'https://hipertextual.com/2021/03/elon-musk-revela-cual-es-mayor-reto-que-se-enfrenta-tesla',
#                'urlToImage': 'https://hipertextual.com/files/2020/01/hipertextual-tesla-iniciara-produccion-model-3-model-europa-junio-2021-2020703699-scaled.jpg'},
#               {'author': 'Hipertextual (Redacción)',
#                'content': 'El rifirrafe entre Elon Musk y Bill Gates continua. '
#                           'Después de algún intercambio previo entre ambos '
#                           'directivos, el fundador de Microsoft cambió su '
#                           'discurso e hizo una serie de declaraciones '
#                           'positivas… [+2305 chars]',
#                'description': 'El rifirrafe entre Elon Musk y Bill Gates '
#                               'continua. Después de algún intercambio previo '
#                               'entre ambos directivos, el fundador de '
#                               'Microsoft cambió su discurso e hizo una serie '
#                               'de declaraciones positivas sobre Tesla. Gates '
#                               'explicó en una entrevista que "hacen fal…',
#                'publishedAt': '2021-02-24T12:28:03Z',
#                'source': {'id': None, 'name': 'Hipertextual'},
#                'title': 'Bill Gates prácticamente admite tener posición en '
#                         'corto de Tesla',
#                'url': 'https://hipertextual.com/2021/02/bill-gates-practicamente-admite-tener-posicion-corto-tesla',
#                'urlToImage': 'https://hipertextual.com/files/2021/02/elon-musk-bill-gates.jpg'},
#               {'author': 'Grace Dean',
#                'content': 'This story originally appeared on Business '
#                           'InsiderUS billionaires would have paid a combined '
#                           '$114 billion for 2020 under an\xa0'
#                           '"ultra-millionaire" tax that Sen. Elizabeth '
#                           'Warren\xa0of Massachusetts propose… [+4192 chars]',
#                'description': 'The 15 richest Americans would contribute about '
#                               'a third of the tax, two tax groups said.',
#                'publishedAt': '2021-03-03T15:45:48Z',
#                'source': {'id': 'business-insider', 'name': 'Business Insider'},
#                'title': "Warren's Wealth Tax: How Much Bezos, Musk, Gates and "
#                         'Zuckerberg Would Pay',
#                'url': 'https://www.businessinsider.com/elizabeth-warren-wealth-tax-bezos-musk-gates-zuckerberg-billionaires-worth-2021-3#momentum-for-a-wealth-tax-has-grown-during-the-pandemic-5',
#                'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1614785874-bezos-gate.jpg'},
#               {'author': 'Graham Rapier',
#                'content': 'Elon Musk on Saturday teased an update about the '
#                           "availability of Tesla's forthcoming Cybertruck as "
#                           'soon as April.\r\n'
#                           '"Update probably in Q2. Cybertruck will be built at '
#                           'Giga Texas, so focus right now i… [+870 chars]',
#                'description': 'Summary List PlacementElon Musk on Saturday '
#                               'teased an update about the availability of '
#                               "Tesla's forthcoming Cybertruck as soon as "
#                               'April.\n'
#                               '"Update probably in Q2. Cybertruck will be '
#                               'built at Giga Texas, so focus right now is on '
#                               'getting that beast built," the CEO…',
#                'publishedAt': '2021-03-07T18:26:34Z',
#                'source': {'id': 'business-insider', 'name': 'Business Insider'},
#                'title': 'Elon Musk teases a Tesla Cybertruck availability '
#                         'update as soon as April (TSLA)',
#                'url': 'https://www.businessinsider.com/elon-musk-teases-tesla-cybertruck-release-date-in-tweet-2021-3',
#                'urlToImage': 'https://i.insider.com/604518cf2db4af00117e3fad?width=1200&format=jpeg'},
#               {'author': 'Matthew DeBord',
#                'content': 'For years, comparisons between Apple and Tesla '
#                           "haven't merely been commonplace they've been "
#                           'expected.\xa0\r\n'
#                           'Some of this could be chalked up to timing. Apple '
#                           'co-founder and CEO Steve Jobs died in 2011, l… '
#                           '[+5195 chars]',
#                'description': 'Summary List PlacementFor years, comparisons '
#                               "between Apple and Tesla haven't merely been "
#                               "commonplace — they've been expected.\xa0\n"
#                               'Some of this could be chalked up to timing. '
#                               'Apple co-founder and CEO Steve Jobs died in '
#                               '2011, leaving the tech world with a visionar…',
#                'publishedAt': '2021-03-14T10:37:00Z',
#                'source': {'id': 'business-insider', 'name': 'Business Insider'},
#                'title': "It's time to retire comparisons between Apple and "
#                         'Tesla, once and for all (TSLA, AAPL)',
#                'url': 'https://www.businessinsider.com/its-time-to-retire-comparisons-between-apple-and-tesla-2021-3',
#                'urlToImage': 'https://i.insider.com/5fe25c2ca644880018193012?width=1200&format=jpeg'},
#               {'author': 'PCMag',
#                'content': 'China is now blocking encrypted chat app Signal, '
#                           'preventing those in the region from sending '
#                           'messages free of government monitoring.\xa0\r\n'
#                           'On Tuesday, users in the country began reporting '
#                           'they were no lo… [+1745 chars]',
#                'description': 'China is now blocking encrypted chat app '
#                               'Signal, preventing those in the region from '
#                               'sending messages free of government '
#                               'monitoring.\xa0\n'
#                               'On Tuesday, users in the country began '
#                               'reporting they were no longer able to send or '
#                               'receive texts via the Signal app. Access…',
#                'publishedAt': '2021-03-16T21:37:57Z',
#                'source': {'id': 'mashable', 'name': 'Mashable'},
#                'title': 'China starts blocking Signal encrypted messaging app',
#                'url': 'https://mashable.com/article/signal-messaging-app-blocked-china/',
#                'urlToImage': 'https://mondrian.mashable.com/2021%252F03%252F16%252F2c%252F21b438a2d0a24f04961887112dd5c7ca.3cb78.jpg%252F1200x630.jpg?signature=SaIBL1-nMoIbCmARbthr7V7tkWM='},
#               {'author': 'Reuters Staff',
#                'content': 'By Reuters Staff\r\n'
#                           '(Reuters) - The third time appeared to be the charm '
#                           'for Elon Musks Starship rocket - until it wasnt.\r\n'
#                           'The latest heavy-duty launch vehicle prototype from '
#                           'SpaceX soared flawlessly in… [+1801 chars]',
#                'description': 'The third time appeared to be the charm for '
#                               "Elon Musk's Starship rocket - until it wasn't.",
#                'publishedAt': '2021-03-04T04:03:00Z',
#                'source': {'id': 'reuters', 'name': 'Reuters'},
#                'title': 'SpaceX Starship rocket prototype nails landing... '
#                         'then blows up - Reuters',
#                'url': 'https://www.reuters.com/article/us-space-exploration-spacex-starship-idUSKCN2AW09F',
#                'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210304&t=2&i=1553693457&r=LYNXNPEH23051&w=800'},
#               {'author': 'Noel Randewich',
#                'content': '(Reuters) - Tesla Incs stock extended losses on '
#                           'Monday and is now down by a third from its January '
#                           'record high, making it the third time in about a '
#                           'year that the electric car makers shares have '
#                           'corre… [+2464 chars]',
#                'description': "Tesla Inc's stock extended losses on Monday and "
#                               'is now down by a third from its January record '
#                               'high, making it the third time in about a year '
#                               "that the electric car maker's shares have "
#                               'corrected that dramatically.',
#                'publishedAt': '2021-03-08T20:55:00Z',
#                'source': {'id': 'reuters', 'name': 'Reuters'},
#                'title': 'Tesla loses a third of its value for the third time '
#                         'in a year - Reuters',
#                'url': 'https://www.reuters.com/article/us-usa-stocks-tesla-graphic-idUSKBN2B02FN',
#                'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210308&t=2&i=1554184552&r=LYNXMPEH271L0&w=800'}],
#  'status': 'ok',
#  'totalResults': 8770}
# Elon Musk changes job title to “Technoking of Tesla”
# Elon Musk reveals why the SN10 Starship exploded
# His Majesty Elon the First, Technoking of Tesla
# Elon Musk won’t sell his NFT song after all
# Japanese billionaire is looking for eight people to join him for a Moon voyage on SpaceX rocket
# Elon Musk, Tesla board sued in lawsuit alleging “erratic” tweets violate fiduciary duty
# Elon Musk says Tesla is expanding its Full Self Driving beta to more drivers
# Your Job Title Is Meaningless, So Share This Instead
# Elon Musk has a new title at Tesla. He's the 'Technoking'
# Elon Musk's Awful Tweets Are the Subject of Yet Another Lawsuit
# Tesla is building a secret 100MW energy storage project in Texas
# How to Find Success Within Your Failures
# Elon Musk explains why Tesla would never share data with China *or* the U.S.
# SpaceX’s floating oil rig spaceship launch pad could be operating later this year according to Elon Musk
# SpaceX nears final assembly of its first massive testing rocket booster for Starship
# Elon Musk made a song about NFTs, and he's selling it as an NFT
# What is Starlink? Elon Musk’s satellite internet service explained
# Tesla’s utility-scale batteries are coming to Texas
# Tesla founder Elon Musk crowns himself TechnoKing | News - The Times
# Elon's Doing Another Bit
# SpaceX set for its third major Starship flight test on Wednesday
# SpaceX Breaks Its Own Falcon 9 Flight Record During Starlink Launch
# Elon Musk reverses course on selling NFT song - Fox Business
# Elon Musk, Bill Gates and Janet Yellen are sending bitcoin tumbling
# Tesla investor sues Musk, board over tweets - Reuters
# SpaceX's first lunar tourist is looking for eight crew members
# SpaceX’s new $850 million raise confirmed in SEC filing
# Elon Musk formally declares himself Technoking of Tesla
# Tesla investor sues Musk, says many tweets in violation of SEC settlement By Reuters - Investing.com
# Musk says would be good for U.S., China to increase mutual trust - Reuters
# Elon Musk gets a new title: 'Technoking of Tesla' - Reuters
# Tesla names Musk 'Technoking' in cryptic regulatory filing - Reuters
# Elon Musk shares family photo from Starbase
# Musk says would be good for U.S., China to increase mutual trust - Reuters
# Elon Musk's Title Changed to 'Technoking Of Tesla'
# Climate Change Will Reshape Silicon Valley As We Know It
# Tesla to build large battery for Texas grid: Bloomberg News - Reuters
# Is Tesla's Bitcoin Gambit Genius or Madness?
# Tesla is building a massive battery for Texas
# Elon Musk es nombrado oficialmente ‘Technoking’ de Tesla
# SpaceX’s Starship prototype flies to 32,000 feet and sticks the landing in third flight test
# Tesla investor sues Musk, says many tweets in violation of SEC settlement - Reuters
# Retail Investors, Elon Musk And The Rise Of Bitcoin - Bitcoin Magazine
# Breakingviews - Capital Calls: Elon Musk’s name games - Reuters
# FOCUS-From Clubhouse to Twitter Spaces, social media grapples with live audio moderation - Reuters
# From Clubhouse to Twitter Spaces, social media grapples with live audio moderation - Reuters
# Elon Musk-led SpaceX's job ad shows plan for Starlink factory in Texas - Reuters Africa
# Kremlin says Elon Musk's Clubhouse invitation to Putin came to nothing - Reuters
# Tesla factory reported hundreds of COVID-19 cases after reopening
# SpaceX posts a clearer look at the Starship SN10 test flight - Yahoo News Canada
# Elon Musk is creating a city in Texas, it will be called Starbase and it would be ruled by 'the Doge'
# Elon Musk Says He Sleeps This Many Hours, Despite All the Projects That Are on His Plate
# Why Bitcoin Is Down Big Today - The Motley Fool Canada
# Elon Musk Responds That 'It Would Be Great' If He Was Investigated For His Dogecoin Memes
# SpaceX launches more Starlink satellites - Associated Press
# Tesla Model 3 production halted until early March, report says - Roadshow
# Elon Musk has cast doubt on the safety of the second COVID-19 jab in a tweet to his millions of followers
# Tesla: “Full self-driving beta” isn’t designed for full self-driving
# Thanks to a 'tweet', Elon Musk is building a power plant near the Gulf of Mexico
# Elon Musk rejected millionaire offer and will no longer sell his tweet as an NFT
# UPDATE 1-Tesla names Musk 'Technoking' in cryptic regulatory filing - Reuters
# Don't let it happen to you! This man lost $ 560,000 to Bitcoin scam on fake Elon Musk account
# Tesla hikes prices, again
# Tesla fell 25% and Elon Musk lost more than $ 15 billion in one day because of Bitcoin?
# 'Technoking' and 'Master of Coin' — Elon Musk's goofy new Tesla titles prove that the company will never have to pay for marketing (TSLA)
# Bill Gates, Elon Musk Both Warn 'Don't Go Too Far with Crypto Speculation'
# Elon Musk decides not to sell his techno song about NFTs as an NFT - CNET
# NFT marketplace OpenSea raises $23 million from a16z
# Tesla and other carmakers want you to pay monthly for feature subscriptions
# Elon Musk lost $27 billion in a rough week for the electric vehicle sector (TSLA)
# Elon Musk's wealth tumbles by $15 billion after Tesla shares dropped 9% in one day
# Elon Musk is no longer the second richest person in the world, look who beat him
# Elon Musk revela cuál es el mayor reto al que se enfrenta Tesla
# Bill Gates prácticamente admite tener posición en corto de Tesla
# Warren's Wealth Tax: How Much Bezos, Musk, Gates and Zuckerberg Would Pay
# Elon Musk teases a Tesla Cybertruck availability update as soon as April (TSLA)
# It's time to retire comparisons between Apple and Tesla, once and for all (TSLA, AAPL)
# China starts blocking Signal encrypted messaging app
# SpaceX Starship rocket prototype nails landing... then blows up - Reuters
# Tesla loses a third of its value for the third time in a year - Reuters

# %% [markdown]
# Lastly, we define a huge string containing the titles of all articles. This string will then be used to collect the words presented in the cloud.

# %%
allText = ''
for i in json['articles']:
    allText += str(i['title'] + ' ') 

wordcloud = WordCloud(max_font_size=40).generate(allText)

# %%
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
